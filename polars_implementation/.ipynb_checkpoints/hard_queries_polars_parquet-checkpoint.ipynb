# %%
import polars as pl
import time
import os

# Log results to a file
def log_results_to_file(result_file, time_elapsed, memory_usage):
    with open(result_file, 'a') as f:
        f.write(f"Times: {time_elapsed}, Memory: {memory_usage}\n")
    if os.path.exists(result_file):
        print(f"File {result_file} created/updated successfully!")
    else:
        print(f"Error: {result_file} was not created.")

def base_hard_polars_queries(log_dir, result_file):
    print(",base_hard_polars_queries")
    df = pl.scan_parquet(log_dir)  # Lazy loading
    query_index = 0
    combinations = [('op_type', 'service_class')]

    for ix, iy in combinations:
        for col in ['disk_io_size_bytes', 'disk_time']:
            query_index += 1
            t1 = time.time()

            res = (
                df.group_by(ix)
                .agg([
                    pl.col(iy).alias(iy),          # Collect the column as is
                    pl.col(col).sum().alias(col)   # Sum aggregation
                ])
                .explode(iy)                      # Explode the column
                .group_by(iy)
                .agg([
                    pl.col(ix).alias(ix),          # Collect column again as is
                    pl.col(col).sum().alias(col)   # Sum aggregation
                ])
            ).collect()  # Collect to materialize the computation

            time_elapsed = time.time() - t1
            memory_usage = res.estimated_size()

            log_results_to_file(result_file, time_elapsed, memory_usage)
            print(f"hard,Q{query_index},{time_elapsed},{memory_usage}")

# IOMAX Hard Polars queries with LazyFrame
def iomax_hard_polars_queries(log_dir, result_file):
    print(",iomax_hard_polars_queries")
    df = pl.scan_parquet(log_dir)  # Lazy loading
    query_index = 0
    combinations = [('op_type', 'service_class')]

    for ix, iy in combinations:
        for col in ['disk_io_size_bytes', 'disk_time']:
            query_index += 1
            t1 = time.time()
            memory_usage = 0
            if query_index == 1:
                agg_result = df.group_by([ix, iy]).agg([
                    pl.col("disk_io_size_bytes").sum(),
                    pl.col("disk_time").sum()
                ]).collect()
                memory_usage = agg_result.estimated_size()

            res = (
                df.group_by(ix)
                .agg([
                    pl.col(iy).alias(iy),
                    pl.col(col).sum()
                ])
                .explode(iy)
                .group_by(iy)
                .agg([
                    pl.col(ix).alias(ix),
                    pl.col(col).sum()
                ])
            )

            time_elapsed = time.time() - t1

            log_results_to_file(result_file, time_elapsed, memory_usage)
            print(f"hard,Q{query_index},{time_elapsed},{memory_usage}")

# Example calls
iomax_hard_polars_queries("../datasets_thesios_io_traces/dataset-125m", "results_rust_hard_queries_parquet/results_parquet_rust_iomax_hard_125m.txt")
# Out:
# ,iomax_hard_polars_queries
